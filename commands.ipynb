# %% [markdown]
# COMMAND LIST COLAB FOR MANAGE DIRECTORIES

# %%
# %pwd   # What location I am right now
# Out:
# '/content/sample_data'

# %%
# %ls #list down directories in current location
# Out:
# sample_data/

# %%
# %cd '/content/sample_data'
# Out:
# /content/sample_data

# %%
# %ls   #list down directories in this location
# Out:
# anscombe.json*                mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md*
